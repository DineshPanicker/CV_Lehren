# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
im = np.arange(255)
im = im[np.newaxis,:]
im= np.repeat(im,30,axis=0)
plt.imshow(im,cmap='gray',vmin=0,vmax=255)

# %%
im = im[np.newaxis,:]

# %%
im.shape
# Out:
# (1, 30, 255)

# %%
im=np.repeat(im,10,axis=0)

# %%
im.shape
# Out:
# (10, 30, 255)

# %%
im
# Out:
# array([[[  0,   1,   2, ..., 252, 253, 254],
#         [  0,   1,   2, ..., 252, 253, 254],
#         [  0,   1,   2, ..., 252, 253, 254],
#         ...,
#         [  0,   1,   2, ..., 252, 253, 254],
#         [  0,   1,   2, ..., 252, 253, 254],
#         [  0,   1,   2, ..., 252, 253, 254]],
#
#        [[  0,   1,   2, ..., 252, 253, 254],
#         [  0,   1,   2, ..., 252, 253, 254],
#         [  0,   1,   2, ..., 252, 253, 254],
#         ...,
#         [  0,   1,   2, ..., 252, 253, 254],
#         [  0,   1,   2, ..., 252, 253, 254],
#         [  0,   1,   2, ..., 252, 253, 254]],
#
#        [[  0,   1,   2, ..., 252, 253, 254],
#         [  0,   1,   2, ..., 252, 253, 254],
#         [  0,   1,   2, ..., 252, 253, 254],
#         ...,
#         [  0,   1,   2, ..., 252, 253, 254],
#         [  0,   1,   2, ..., 252, 253, 254],
#         [  0,   1,   2, ..., 252, 253, 254]],
#
#        ...,
#
#        [[  0,   1,   2, ..., 252, 253, 254],
# ...

# %%
plt.imshow(im,cmap='grey')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 plt.imshow(im,cmap='grey')
#
# File D:\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3358, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3337 @_copy_docstring_and_deprecators(Axes.imshow)
#    3338 def imshow(
#    3339     X: ArrayLike | PIL.Image.Image,
#    (...)
#    3356     **kwargs,
#    3357 ) -> AxesImage:
# -> 3358     __ret = gca().imshow(
#    3359         X,
#    3360         cmap=cmap,
#    3361         norm=norm,
#    3362         aspect=aspect,
#    3363         interpolation=interpolation,
#    3364         alpha=alpha,
#    3365         vmin=vmin,
#    3366         vmax=vmax,
#    3367         origin=origin,
#    3368         extent=extent,
# ...

# %% [markdown]
# ## PROCESSING GRAYSCALE

# %%
im = plt.imread(r'A:\RWU\CV\CV_Python\albert-einstein_gray.jpg')

# %%
type(im)
# Out:
# numpy.ndarray

# %%
im.shape
# Out:
# (949, 728)

# %%
im.dtype
# Out:
# dtype('uint8')

# %%
plt.imshow(im,cmap='grey')

# %%
im
# Out:
# array([[85, 85, 85, ..., 62, 62, 62],
#        [85, 85, 85, ..., 64, 65, 64],
#        [85, 85, 85, ..., 59, 59, 58],
#        ...,
#        [36, 42, 42, ..., 36, 42, 47],
#        [29, 37, 37, ..., 36, 43, 44],
#        [33, 40, 37, ..., 35, 43, 42]], dtype=uint8)

# %%
im[24,313]
# Out:
# 80

# %%
im[23:100,40:100] = 255
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 im[23:100,40:100] = 255
#
# ValueError: assignment destination is read-only

# %%
im[23,100]=200
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 im[23,100]=200
#
# ValueError: assignment destination is read-only

# %%
im2 = im.copy()

# %%
im2[23,100]=200

# %%
im2[23:100,40:100] = 255

# %%
plt.imshow(im2,cmap='gray')

# %%
im2[300:400,40:100] = 0

# %%
plt.imshow(im2,cmap='gray')

# %%
plt.imsave(r'A:\RWU\CV\CV_Python\albert-einstein_gray_modified.jpg',im2,cmap='gray')

# %%
im = plt.imread(r'A:\RWU\First Sem\CV\CV_Python\albert-einstein_gray.jpg')
im3=im.copy()

im3[350:430,300:400] = 0 #for left eye
im3[350:430,440:540] = 0 #for right eye

plt.imshow(im3, cmap='gray')

# %%
pip install opencv-contrib-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/45.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/45.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/45.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/45.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/45.5 MB 409.6 kB/s eta 0:01:52
#    ---------------------------------------- 0.1/45.5 MB 409.6 kB/s eta 0:01:52
#    ---------------------------------------- 0.1/45.5 MB 467.6 kB/s eta 0:01:38
#    ---------------------------------------- 0.1/45.5 MB 423.5 kB/s eta 0:01:48
#    ---------------------------------------- 0.1/45.5 MB 423.5 kB/s eta 0:01:48
#    ---------------------------------------- 0.1/45.5 MB 340.5 kB/s eta 0:02:14
#    ---------------------------------------- 0.2/45.5 MB 388.2 kB/s eta 0:01:57
# ...

# %%
import cv2

# %%
img = cv2.imread(r'A:\RWU\First Sem\CV\CV_Python\albert-einstein_gray.jpg',cv2.IMREAD_GRAYSCALE)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (949, 728)

# %%
cv2.imshow('Gray',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img[500:700,500:600] = 255

# %%
cv2.imshow('Gray',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imwrite(r"A:\RWU\First Sem\CV\CV_Python\albert-einstein_gray_opencv.jpg",img)
# Out:
# True
